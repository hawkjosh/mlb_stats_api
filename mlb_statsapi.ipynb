# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mlb_statsapi_utils as mlb

# %%
from pprint import pp
pp(mlb.Team().get_teams())
# Out:
# [{'id': 141,
#   'franchiseName': 'Toronto',
#   'clubName': 'Blue Jays',
#   'teamName': 'Toronto Blue Jays',
#   'league': 'American League',
#   'division': 'AL East',
#   'divisionSort': 22},
#  {'id': 110,
#   'franchiseName': 'Baltimore',
#   'clubName': 'Orioles',
#   'teamName': 'Baltimore Orioles',
#   'league': 'American League',
#   'division': 'AL East',
#   'divisionSort': 22},
#  {'id': 139,
#   'franchiseName': 'Tampa Bay',
#   'clubName': 'Rays',
#   'teamName': 'Tampa Bay Rays',
#   'league': 'American League',
#   'division': 'AL East',
#   'divisionSort': 22},
#  {'id': 111,
#   'franchiseName': 'Boston',
#   'clubName': 'Red Sox',
#   'teamName': 'Boston Red Sox',
#   'league': 'American League',
#   'division': 'AL East',
#   'divisionSort': 22},
#  {'id': 147,
#   'franchiseName': 'New York',
#   'clubName': 'Yankees',
#   'teamName': 'New York Yankees',
#   'league': 'American League',
#   'division': 'AL East',
#   'divisionSort': 22},
#  {'id': 114,
# ...

# %%
teams = mlb.Team().get_teams()

# %%
pp(sorted(teams, key=lambda x: x['division']))

# %%
from pprint import pp
pp(mlb.Team().get_team(team_id=144))

# %%
for team in mlb.Team().get_teams():
    pp(mlb.Team().get_team(team_id=team['id']))

# %%
mlb.Team().get_team(team_name="braves")
