# %%
# %load_ext autoreload
# %autoreload 2

# %%
import python_mlb_statsapi_utils as mlb

# %%
mlb.Team().get_teams()
# Out:
# [{'id': 108,
#   'name': 'Los Angeles Angels',
#   'franchiseName': 'Los Angeles',
#   'teamName': 'Angels',
#   'clubName': 'Angels',
#   'league': 'American League',
#   'division': 'American League West',
#   'springLeague': 'Cactus League'},
#  {'id': 117,
#   'name': 'Houston Astros',
#   'franchiseName': 'Houston',
#   'teamName': 'Astros',
#   'clubName': 'Astros',
#   'league': 'American League',
#   'division': 'American League West',
#   'springLeague': 'Grapefruit League'},
#  {'id': 133,
#   'name': 'Oakland Athletics',
#   'franchiseName': 'Oakland',
#   'teamName': 'Athletics',
#   'clubName': 'Athletics',
#   'league': 'American League',
#   'division': 'American League West',
#   'springLeague': 'Cactus League'},
#  {'id': 141,
#   'name': 'Toronto Blue Jays',
#   'franchiseName': 'Toronto',
#   'teamName': 'Blue Jays',
#   'clubName': 'Blue Jays',
#   'league': 'American League',
#   'division': 'American League East',
#   'springLeague': 'Grapefruit League'},
# ...

# %%
mlb.Team().get_teams()
# Out:
# [{'id': 108,
#   'name': 'Los Angeles Angels',
#   'franchiseName': 'Los Angeles',
#   'teamName': 'Angels',
#   'shortName': 'LA Angels',
#   'teamAbbr': 'LAA',
#   'firstYear': '1961',
#   'league': 'American League',
#   'leagueId': 103,
#   'division': 'American League West',
#   'divisionId': 200,
#   'springLeague': 'Cactus League',
#   'springLeagueId': 114,
#   'springVenueId': 2500,
#   'venue': 'Angel Stadium',
#   'venueId': 1},
#  {'id': 117,
#   'name': 'Houston Astros',
#   'franchiseName': 'Houston',
#   'teamName': 'Astros',
#   'shortName': 'Houston',
#   'teamAbbr': 'HOU',
#   'firstYear': '1962',
#   'league': 'American League',
#   'leagueId': 103,
#   'division': 'American League West',
#   'divisionId': 200,
#   'springLeague': 'Grapefruit League',
#   'springLeagueId': 115,
#   'springVenueId': 5000,
#   'venue': 'Minute Maid Park',
#   'venueId': 2392},
#  {'id': 133,
#   'name': 'Oakland Athletics',
#   'franchiseName': 'Oakland',
# ...

# %%
mlb.Team().get_team(team_id=144)
# Out:
# {'id': 144,
#  'name': 'Atlanta Braves',
#  'franchiseName': 'Atlanta',
#  'clubName': 'Braves',
#  'shortName': 'Atlanta',
#  'teamAbbr': 'ATL',
#  'league': 'National League',
#  'division': 'National League East',
#  'venue': {'name': 'Truist Park',
#   'capacity': 41149,
#   'turfType': 'Grass',
#   'roofType': 'Open',
#   'leftLine': 335,
#   'left': 375,
#   'leftCenter': 385,
#   'center': 400,
#   'rightCenter': 375,
#   'right': None,
#   'rightLine': 325},
#  'springLeague': {'name': 'Grapefruit League', 'venue': 'CoolToday Park'},
#  'firstYear': '1871'}

# %%
mlb.Team().get_team_venue(team_id=144)
# Out:
# Venue(id=4705, link=/api/v1/venues/4705, name=Truist Park, fieldinfo=FieldInfo(capacity=41149, turftype=Grass, rooftype=Open, leftline=335, left=375, leftcenter=385, center=400, rightcenter=375, rightline=325), active=True, season=2024)

# %%
mlb.Team().get_team_spring_venue(team_id=144)
# Out:
# Venue(id=5380, link=/api/v1/venues/5380, name=CoolToday Park, fieldinfo=FieldInfo(capacity=8500, turftype=Grass, rooftype=Open, leftline=335, left=385, center=400, right=375, rightline=325), active=True, season=2024)

# %%
mlb.Team().get_team(team_id=144)
# Out:
# Team(id=144, link=/api/v1/teams/144, name=Atlanta Braves, springleague=League(id=115, link=/api/v1/league/115, name=Grapefruit League, abbreviation=GL), allstarstatus=N, season=2024, venue=Venue(id=4705, link=/api/v1/venues/4705, name=Truist Park), springvenue=Venue(id=5380, link=/api/v1/venues/5380), teamcode=atl, filecode=atl, abbreviation=ATL, teamname=Braves, locationname=Atlanta, firstyearofplay=1871, league=League(id=104, link=/api/v1/league/104, name=National League), division=Division(id=204, link=/api/v1/divisions/204, name=National League East), sport=Sport(id=1, link=/api/v1/sports/1, name=Major League Baseball), shortname=Atlanta, franchisename=Atlanta, clubname=Braves, active=True)

# %%
mlb.Team().get_team(team_name="Atlanta Braves")
# Out:
# Team(id=144, link=/api/v1/teams/144, name=Atlanta Braves, springleague=League(id=115, link=/api/v1/league/115, name=Grapefruit League, abbreviation=GL), allstarstatus=N, season=2024, venue=Venue(id=4705, link=/api/v1/venues/4705, name=Truist Park), springvenue=Venue(id=5380, link=/api/v1/venues/5380), teamcode=atl, filecode=atl, abbreviation=ATL, teamname=Braves, locationname=Atlanta, firstyearofplay=1871, league=League(id=104, link=/api/v1/league/104, name=National League), division=Division(id=204, link=/api/v1/divisions/204, name=National League East), sport=Sport(id=1, link=/api/v1/sports/1, name=Major League Baseball), shortname=Atlanta, franchisename=Atlanta, clubname=Braves, active=True)

# %%
mlb.Team().get_coaches(team_id=144)
# Out:
# [Coach(id=492535, link=/api/v1/people/492535, fullname=Brian Snitker, jerseynumber=43, job=Manager, jobid=MNGR, title=Manager),
#  Coach(id=124054, link=/api/v1/people/124054, fullname=Walt Weiss, jerseynumber=4, job=Bench Coach, jobid=COAB, title=Bench Coach/Infield Coach),
#  Coach(id=492899, link=/api/v1/people/492899, fullname=Rick Kranitz, jerseynumber=39, job=Pitching Coach, jobid=COAP, title=Pitching Coach),
#  Coach(id=121983, link=/api/v1/people/121983, fullname=Kevin Seitzer, jerseynumber=34, job=Hitting Coach, jobid=COAT, title=Hitting Coach),
#  Coach(id=114961, link=/api/v1/people/114961, fullname=Tom Goodwin, jerseynumber=88, job=First Base Coach, jobid=COA1, title=First Base Coach),
#  Coach(id=449168, link=/api/v1/people/449168, fullname=Matt Tuiasosopo, jerseynumber=89, job=Third Base Coach, jobid=COA3, title=Third Base Coach),
#  Coach(id=467728, link=/api/v1/people/467728, fullname=Erick Abreu, jerseynumber=85, job=Bullpen Coach, jobid=COAU, title=Bullpen Coach),
# ...

# %%
mlb.Team().get_coaches(team_name="Atlanta Braves")
# Out:
# [Coach(id=492535, link=/api/v1/people/492535, fullname=Brian Snitker, jerseynumber=43, job=Manager, jobid=MNGR, title=Manager),
#  Coach(id=124054, link=/api/v1/people/124054, fullname=Walt Weiss, jerseynumber=4, job=Bench Coach, jobid=COAB, title=Bench Coach/Infield Coach),
#  Coach(id=492899, link=/api/v1/people/492899, fullname=Rick Kranitz, jerseynumber=39, job=Pitching Coach, jobid=COAP, title=Pitching Coach),
#  Coach(id=121983, link=/api/v1/people/121983, fullname=Kevin Seitzer, jerseynumber=34, job=Hitting Coach, jobid=COAT, title=Hitting Coach),
#  Coach(id=114961, link=/api/v1/people/114961, fullname=Tom Goodwin, jerseynumber=88, job=First Base Coach, jobid=COA1, title=First Base Coach),
#  Coach(id=449168, link=/api/v1/people/449168, fullname=Matt Tuiasosopo, jerseynumber=89, job=Third Base Coach, jobid=COA3, title=Third Base Coach),
#  Coach(id=467728, link=/api/v1/people/467728, fullname=Erick Abreu, jerseynumber=85, job=Bullpen Coach, jobid=COAU, title=Bullpen Coach),
# ...

# %%
mlb.Team().get_roster(team_id=144)
# Out:
# [Player(id=607481, link=/api/v1/people/607481, primaryposition=Position(code='1', name='Pitcher', type='Pitcher', abbreviation='P'), fullname=Aaron Bummer, jerseynumber=49, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=594807, link=/api/v1/people/594807, primaryposition=Position(code='7', name='Outfielder', type='Outfielder', abbreviation='LF'), fullname=Adam Duvall, jerseynumber=14, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=663586, link=/api/v1/people/663586, primaryposition=Position(code='5', name='Third Base', type='Infielder', abbreviation='3B'), fullname=Austin Riley, jerseynumber=27, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=605119, link=/api/v1/people/605119, primaryposition=Position(code='5', name='Third Base', type='Infielder', abbreviation='3B'), fullname=Brian Anderson, jerseynumber=15, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
# ...

# %%
mlb.Team().get_roster(team_name="Atlanta Braves")
# Out:
# [Player(id=607481, link=/api/v1/people/607481, primaryposition=Position(code='1', name='Pitcher', type='Pitcher', abbreviation='P'), fullname=Aaron Bummer, jerseynumber=49, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=594807, link=/api/v1/people/594807, primaryposition=Position(code='7', name='Outfielder', type='Outfielder', abbreviation='LF'), fullname=Adam Duvall, jerseynumber=14, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=663586, link=/api/v1/people/663586, primaryposition=Position(code='5', name='Third Base', type='Infielder', abbreviation='3B'), fullname=Austin Riley, jerseynumber=27, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
#  Player(id=605119, link=/api/v1/people/605119, primaryposition=Position(code='5', name='Third Base', type='Infielder', abbreviation='3B'), fullname=Brian Anderson, jerseynumber=15, parentteamid=144, status={'code': 'A', 'description': 'Active'}),
# ...

# %%
mlb.Venue().get_venue(venue_name="Truist Park")
# Out:
# Venue(id=4705, link=/api/v1/venues/4705, name=Truist Park, fieldinfo=FieldInfo(capacity=41149, turftype=Grass, rooftype=Open, leftline=335, left=375, leftcenter=385, center=400, rightcenter=375, rightline=325), active=True, season=2024)
